# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('/content/drive/MyDrive/Disease Prediction/Dataset/covid.csv')
data.head()
# Out:
#        id  sex  patient_type  entry_date date_symptoms   date_died  intubed  \
# 0  16169f    2             1  04-05-2020    02-05-2020  9999-99-99       97
# 1  1009bf    2             1  19-03-2020    17-03-2020  9999-99-99       97
# 2  167386    1             2  06-04-2020    01-04-2020  9999-99-99        2
# 3  0b5948    2             2  17-04-2020    10-04-2020  9999-99-99        2
# 4  0d01b5    1             2  13-04-2020    13-04-2020  22-04-2020        2
#
#    pneumonia  age  pregnancy  ...  inmsupr  hypertension  other_disease  \
# 0          2   27         97  ...        2             2              2
# 1          2   24         97  ...        2             2              2
# 2          2   54          2  ...        2             2              2
# 3          1   30         97  ...        2             2              2
# 4          2   60          2  ...        2             1              2
#
#    cardiovascular  obesity  renal_chronic  tobacco  contact_other_covid  \
# ...

# %%
data.shape
# Out:
# (566602, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566602 entries, 0 to 566601
# Data columns (total 23 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   566602 non-null  object
#  1   sex                  566602 non-null  int64
#  2   patient_type         566602 non-null  int64
#  3   entry_date           566602 non-null  object
#  4   date_symptoms        566602 non-null  object
#  5   date_died            566602 non-null  object
#  6   intubed              566602 non-null  int64
#  7   pneumonia            566602 non-null  int64
#  8   age                  566602 non-null  int64
#  9   pregnancy            566602 non-null  int64
#  10  diabetes             566602 non-null  int64
#  11  copd                 566602 non-null  int64
#  12  asthma               566602 non-null  int64
#  13  inmsupr              566602 non-null  int64
#  14  hypertension         566602 non-null  int64
# ...

# %%
data.drop(columns={'entry_date','date_died','date_symptoms','id'},axis=1,inplace=True)

# %%
data['covid_res'].replace([1,2,3],[1,0,2],inplace=True)

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'covid_res', data = data)

# %%
data=data[data['covid_res']!=2]

# %%
sns.set_style('whitegrid')
sns.countplot(x = 'covid_res', data = data)

# %%
plt.figure(figsize=(30,8))
sns.countplot(x=data['age'])

# %%
data=data[data['intubed']!=97]
data['intubed'].value_counts().sort_index().plot.bar()
plt.title('Intubed')
# Out:
# Text(0.5, 1.0, 'Intubed')

# %%
data=data[data['intubed']!=99]
data['intubed'].value_counts().to_frame()
# Out:
#    intubed
# 2    98321
# 1     9103

# %%
data=data[data['pneumonia']!=99]
data['pneumonia'].value_counts().sort_index().plot.bar()
plt.title('pneumonia')
# Out:
# Text(0.5, 1.0, 'pneumonia')

# %%
data=data[data['pregnancy']!=97]
data=data[data['pregnancy']!=98]
data['pregnancy'].value_counts().sort_index().plot.bar()
plt.title('Pregnancy')
# Out:
# Text(0.5, 1.0, 'Pregnancy')

# %%
data=data[data['diabetes']!=98]
data['diabetes'].value_counts().sort_index().plot.bar()
plt.title('Diabetes')
# Out:
# Text(0.5, 1.0, 'Diabetes')

# %%
data=data[data['copd']!=98]
data['copd'].value_counts().sort_index().plot.bar()
plt.title('COPD')
# Out:
# Text(0.5, 1.0, 'COPD')

# %%
data=data[data['asthma']!=98]
data['asthma'].value_counts().sort_index().plot.bar()
plt.title('Asthma')
# Out:
# Text(0.5, 1.0, 'Asthma')

# %%
data=data[data['inmsupr']!=98]
data['inmsupr'].value_counts().sort_index().plot.bar()
plt.title('Inmsupr')
# Out:
# Text(0.5, 1.0, 'Inmsupr')

# %%
data=data[data['hypertension']!=98]
data['hypertension'].value_counts().sort_index().plot.bar()
plt.title('Hypertension')
# Out:
# Text(0.5, 1.0, 'Hypertension')

# %%
data=data[data['other_disease']!=98]
data['other_disease'].value_counts().sort_index().plot.bar()
plt.title('Other Disease')
# Out:
# Text(0.5, 1.0, 'Other Disease')

# %%
data=data[data['cardiovascular']!=98]
data['cardiovascular'].value_counts().sort_index().plot.bar()
plt.title('Cardiovascular')
# Out:
# Text(0.5, 1.0, 'Cardiovascular')

# %%
data=data[data['obesity']!=98]
data['obesity'].value_counts().sort_index().plot.bar()
plt.title('Obesity')
# Out:
# Text(0.5, 1.0, 'Obesity')

# %%
data=data[data['renal_chronic']!=98]
data['renal_chronic'].value_counts().sort_index().plot.bar()
plt.title('Renal Chronic')
# Out:
# Text(0.5, 1.0, 'Renal Chronic')

# %%
data=data[data['tobacco']!=98]
print(data['tobacco'].value_counts())
data['tobacco'].value_counts().sort_index().plot.bar()
plt.title('Tobacco')
# Out:
# 2    40303
# 1     1988
# Name: tobacco, dtype: int64
# Text(0.5, 1.0, 'Tobacco')

# %%
data=data[data['contact_other_covid']!=99]
data['contact_other_covid'].value_counts().sort_index().plot.bar()
plt.title('Contact other covid')
# Out:
# Text(0.5, 1.0, 'Contact other covid')

# %%
data=data[data['icu']!=99]
data=data[data['icu']!=97]

data['icu'].value_counts().sort_index().plot.bar()
plt.title('ICU')
# Out:
# Text(0.5, 1.0, 'ICU')

# %%
data.reset_index(drop=True,inplace=True)
data.head(10)
# Out:
#    sex  patient_type  intubed  pneumonia  age  pregnancy  diabetes  copd  \
# 0    1             2        2          2   25          2         2     2
# 1    1             2        2          2   52          2         2     2
# 2    1             2        2          1   51          2         2     2
# 3    1             2        1          1   67          2         1     2
# 4    1             2        2          1   59          2         1     2
# 5    1             2        2          2   52          2         1     2
# 6    1             2        2          1   54          2         2     2
# 7    1             2        2          1   78          2         2     2
# 8    1             2        2          1   80          2         1     2
# 9    1             2        2          2   40          2         2     2
#
#    asthma  inmsupr  hypertension  other_disease  cardiovascular  obesity  \
# 0       2        2             2              2               2        2
# ...

# %%
correlation=data.corr()
print(correlation['covid_res'].sort_values(ascending=False))
# Out:
# covid_res              1.000000
# age                    0.202211
# other_disease          0.094249
# inmsupr                0.083115
# renal_chronic          0.058039
# cardiovascular         0.046820
# pregnancy              0.046104
# copd                   0.045160
# tobacco                0.028987
# asthma                 0.010103
# icu                   -0.014981
# contact_other_covid   -0.041890
# intubed               -0.053427
# hypertension          -0.079742
# diabetes              -0.083567
# obesity               -0.114613
# pneumonia             -0.205502
# sex                         NaN
# patient_type                NaN
# Name: covid_res, dtype: float64

# %%
plt.figure(figsize=(15,12))
sns.heatmap(correlation,annot=True,cmap='viridis',square=True,vmax=0.8)

# %%
features=['sex', 'patient_type', 'intubed', 'pneumonia', 'age', 'pregnancy',
       'diabetes', 'copd', 'asthma', 'inmsupr', 'hypertension',
       'other_disease', 'cardiovascular', 'obesity', 'renal_chronic',
       'tobacco', 'contact_other_covid', 'icu']
list(enumerate(features))
# Out:
# [(0, 'sex'),
#  (1, 'patient_type'),
#  (2, 'intubed'),
#  (3, 'pneumonia'),
#  (4, 'age'),
#  (5, 'pregnancy'),
#  (6, 'diabetes'),
#  (7, 'copd'),
#  (8, 'asthma'),
#  (9, 'inmsupr'),
#  (10, 'hypertension'),
#  (11, 'other_disease'),
#  (12, 'cardiovascular'),
#  (13, 'obesity'),
#  (14, 'renal_chronic'),
#  (15, 'tobacco'),
#  (16, 'contact_other_covid'),
#  (17, 'icu')]

# %%
plt.figure(figsize=(15,15))
for i in enumerate(features):
    plt.subplot(6,3,i[0]+1)
    sns.countplot(i[1],hue='covid_res',data=data)
    plt.xticks(rotation=45,size=8)
    plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
X = data[['sex', 'patient_type', 'intubed', 'pneumonia', 'age', 'pregnancy',
       'diabetes', 'copd', 'asthma', 'inmsupr', 'hypertension',
       'other_disease', 'cardiovascular', 'obesity', 'renal_chronic',
       'tobacco', 'contact_other_covid', 'icu']]
y = data['covid_res']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# %%
print("Train Set: ", X_train.shape, y_train.shape)
print("Test Set: ", X_test.shape, y_test.shape)
# Out:
# Train Set:  (16281, 18) (16281,)
# Test Set:  (4071, 18) (4071,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB

# %%
RANDOM_STATE = 42

model_params = {
    'SVC': {
        'model': SVC(random_state=RANDOM_STATE),
        'params' : {
            'C': [1,2,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(max_depth=7, min_samples_split=5, min_samples_leaf=5, random_state=RANDOM_STATE),
        'params' : {
            'n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    },
    'naive_bayes_gaussian': {
        'model': GaussianNB(var_smoothing=1e-2),
        'params': {}
    },
    'naive_bayes_multinomial': {
        'model': MultinomialNB(),
        'params': {}
    },
    'K-nearest neighbors': {
        'model': KNeighborsClassifier(),
        'params': {}
    },
    'Gradient boosting classifiers': {
        'model': GradientBoostingClassifier(
                   learning_rate=0.005, n_estimators=30, random_state=RANDOM_STATE),
        'params': {
            'learning_rate': [0.001, 0.01, 0.005],
            'n_estimators': [10,20,30]
        }
    },
    'decision_tree': {
        'model': DecisionTreeClassifier(max_depth=2, random_state=RANDOM_STATE),
        'params': {
            'criterion': ['gini','entropy'],
            
        }
    }     
}

# %%
from sklearn.model_selection import GridSearchCV

scores = []
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'Model': model_name,
        'Accuracy': clf.best_score_,
        'best_params': clf.best_params_
    })
    
result = pd.DataFrame(scores,columns=['Model','Accuracy','best_params'])

# %%
comparison = result.sort_values(by = "Accuracy", ascending = False)
comparison
# Out:
#                            Model  Accuracy  \
# 1                  random_forest  0.666789
# 2            logistic_regression  0.661752
# 0                            SVC  0.658374
# 3           naive_bayes_gaussian  0.648793
# 7                  decision_tree  0.646336
# 6  Gradient boosting classifiers  0.623917
# 4        naive_bayes_multinomial  0.623794
# 5            K-nearest neighbors  0.618573
#
#                                    best_params
# 1                         {'n_estimators': 10}
# 2                                     {'C': 5}
# 0                   {'C': 20, 'kernel': 'rbf'}
# 3                                           {}
# 7                        {'criterion': 'gini'}
# 6  {'learning_rate': 0.01, 'n_estimators': 30}
# 4                                           {}
# 5                                           {}

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier
classifier1 = RandomForestClassifier(max_depth=7, min_samples_split=5, min_samples_leaf=5, random_state=RANDOM_STATE)
classifier1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=7, min_samples_leaf=5, min_samples_split=5,
#                        random_state=42)

# %%
y_pred = classifier1.predict(X_test)
y_pred[:10]
# Out:
# array([1, 1, 0, 1, 1, 1, 0, 0, 1, 1])

# %%
print(f"Train Accuracy is: {round(classifier1.score(X_train, y_train)*100,2)}%")
print(f"Test Accuracy is : {round(classifier1.score(X_test, y_test)*100,2)}%")
# Out:
# Train Accuracy is: 68.25%
# Test Accuracy is : 66.32%

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.38      0.49      1706
#            1       0.66      0.87      0.75      2365
#
#     accuracy                           0.66      4071
#    macro avg       0.67      0.62      0.62      4071
# weighted avg       0.67      0.66      0.64      4071

# %%
conf_mat = confusion_matrix(y_test,y_pred)
fig, ax = plt.subplots(figsize=(5,5))
sns.heatmap(conf_mat, annot=True, fmt='d')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc #for model evaluation
from matplotlib import pyplot
fig, (ax2) = plt.subplots(figsize = (8,6))
        #roc-curve
fpr, tpr, thresholds_roc = roc_curve(y_test,y_pred)
roc_auc = auc(fpr,tpr)
ax2.plot(fpr,tpr, label = " AUROC = {:0.2f}".format(roc_auc))
ax2.plot([0,1], [0,1], 'r', linestyle = "--", lw = 2)
ax2.set_xlabel("False Positive Rate", fontsize = 14)
ax2.set_ylabel("True Positive Rate", fontsize = 14)
ax2.set_title("ROC Curve", fontsize = 18)
ax2.legend(loc = 'best')
plt.title('ROC curve for RandomForestClassifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
        #find default threshold
close_default = np.argmin(np.abs(thresholds_roc - 0.5))
ax2.plot(fpr[close_default], tpr[close_default], 'o', markersize = 8)
plt.tight_layout()
